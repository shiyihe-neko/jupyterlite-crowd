# %% [markdown]
# # Data Cleaning Task - Demo
#
# In this task, you will clean the provided dataset `demo.csv`.
#
# Please follow the instructions below to read the data, save the file with the required name.
# Once you have finished the task, run the submission code block (don’t forget to enter the required arguments before running it).

# %% [markdown]
# ## 1. Provide Your Prolific ID (and RUN the code cell!)
# Replace "Your Prolific ID" with your actual Prolific ID in the code cell below.
# Don’t skip this step, it ensures that your work is correctly linked to your submission.

# %%
# Replace "Your Prolific ID" with your actual Prolific ID.
participant_id = "Your Prolific ID" ## ⚠️⚠️⚠️ don't miss this part!!! Run this code cell after replacing the text!

# %% [markdown]
# ## 2. Load the Dataset

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('/drive/datasets/demo.csv')
df.head()

# %% [markdown]
# ## 3. Data Cleaning
#
# Perform you data cleaning process below.

# %%
# Your data cleaning steps ...

# %%
# Your data cleaning steps ...

# %%
# Your data cleaning steps ...

# %% [markdown]
# ## 4. Save Cleaned Data and Submit Files
#
# Run the following code blocks to save and submit your files. Don't change the save path we provided, it ensures your cleaned DataFrame is correctly submitted.
#
# It might take a few minutes for the upload to complete. Please wait until you see the message indicating that the upload was successful.

# %%
# initial setup for submission
import requests
from upload_helper import submit_all_files 

df_cleaned.to_csv('/drive/datasets/demo_cleaned.csv', index=False) ## ⚠️⚠️⚠️ If your cleaned DataFrame is not named "df_cleaned", please update the variable name accordingly before saving.

submit_all_files(
    data_file_path="/drive/datasets/demo_cleaned.csv", 
    notebook_file_path="task_demo.ipynb", 
    participant_id=participant_id
)
